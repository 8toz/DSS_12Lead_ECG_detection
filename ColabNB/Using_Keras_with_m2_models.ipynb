# %% [markdown]
# # NUMERO DE PRUEBA

# %%
TRIAL_NUMBER = 'trial_12_512_SE_ResNet_LSTM_1'

# %% [markdown]
# # Dependencias

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Layer, Dense, Reshape, BatchNormalization
from tensorflow.keras.layers import LayerNormalization, Activation, Input, Dropout, Flatten, LeakyReLU, LSTM
from tensorflow.keras.layers import Bidirectional, TimeDistributed,Conv1D, Conv2D,Conv2DTranspose, AveragePooling1D
from tensorflow.keras.layers import MaxPooling1D, UpSampling1D, ZeroPadding1D, Lambda, Add, Cropping1D, Embedding, Concatenate
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.models import load_model,save_model
from tensorflow.keras.losses import BinaryCrossentropy
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
from tensorflow import convert_to_tensor
from keras.callbacks import ReduceLROnPlateau

import os, random
import numpy as np
import progressbar
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings
import pickle

from functools import partial
from IPython import display
from tensorflow.keras.utils import plot_model
from scipy.io import loadmat
from scipy.signal import butter, lfilter, resample
import pandas as pd

from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#GLOBAL VARIABLES
csv_file = pd.read_csv('/content/drive/My Drive/TFM_DATA/Dx_snomed_valid.csv', delimiter = ';')
DATASET = 'm2_512_grouped.pkl'
DRIVE_PATH = '/content/drive/My Drive/TFM_DATA/'
RESULTS_PATH = '/content/drive/My Drive/TFM_RESULTS'
FILE_NAME = 'trial_details.txt'
TRIAL_PATH = str(os.path.join(RESULTS_PATH,TRIAL_NUMBER))

try:
  os.mkdir(TRIAL_PATH)
except:
  print(f'The file test {TRIAL_NUMBER} already exist, if you continue the\
  current test will be overrided, change the TRIAL_NUMBER to create a new\
  test.')
# Out:
# The file test trial_12_512_SE_ResNet_LSTM_1 already exist, if you continue the  current test will be overrided, change the TRIAL_NUMBER to create a new  test.

# %% [markdown]
# # Clasificación

# %%
import pickle
dataset = pickle.load(open(str(os.path.join(DRIVE_PATH, DATASET)), 'rb'))
dataset.shape
# Out:
# (37716, 5)

# %% [markdown]
# # Data transformation V2

# %%
def group_data(dataset):
  data_grouped = pd.DataFrame(columns=['file', 'age', 'sex', 'ecg', 'class'])
  unique_files = dataset['file'].unique()
  file_grouped = []
  age_grouped = []
  sex_grouped = []
  class_grouped = []
  ecg_grouped = []

  for x in unique_files:
    filtro = dataset[dataset['file']==x]

    file_grouped.append(filtro['file'].iloc[0])
    age_grouped.append(filtro['age'].iloc[0])
    sex_grouped.append(filtro['sex'].iloc[0])
    class_grouped.append(filtro['class'].iloc[0])
    ecg_grouped.append(np.stack(filtro['ecg']))


  data_grouped['file'] = file_grouped
  data_grouped['age'] = age_grouped
  data_grouped['sex'] = sex_grouped
  data_grouped['class'] = class_grouped
  data_grouped['ecg'] = ecg_grouped

  return data_grouped

# %%
a = group_data(p1)

# %%
p1 = pickle.load(open(str(os.path.join(DRIVE_PATH, 'm2_512_p1.pkl')), 'rb'))
p2 = pickle.load(open(str(os.path.join(DRIVE_PATH, 'm2_512_p2.pkl')), 'rb'))
a = pd.concat([p1, p2])

# %%
a.to_pickle('/content/drive/MyDrive/TFM_DATA/m2_512_grouped.pkl')

# %% [markdown]
# # Train Validation Test Splitting

# %%
def transform_dims(sample):
  lista = []
  [lista.append(x) for x in sample]
  lista = np.array(lista)
  return lista

# %%
from sklearn.model_selection import StratifiedShuffleSplit

X, y = dataset[['age', 'sex', 'ecg']], dataset[['class']]

Data_train, Data_val, y_train, y_val = train_test_split(X,
                                                      y,
                                                      test_size=0.2,
                                                      shuffle=True,
                                                      random_state=42)

Data_val, Data_test, y_val, y_test = train_test_split(Data_val,
                                                      y_val,
                                                      test_size=0.5,
                                                      shuffle=True,
                                                      random_state=42)

# Transformamos los datos datos de train para hacerlos compatibles con Keras
X_train, qual_train = Data_train[['ecg']], Data_train[['age', 'sex']]
X_train = np.squeeze(np.array(X_train))
y_train = np.squeeze(np.array(y_train))
X_train = transform_dims(X_train)
y_train = transform_dims(y_train)
#X_train = X_train.reshape(-1,3072)

print('------TRAIN------')
print(X_train.shape)
print(qual_train.shape)
print(y_train.shape)

# Transformamos los datos datos de train para hacerlos compatibles con Keras
X_val, qual_val = Data_val[['ecg']], Data_val[['age', 'sex']]
X_val = np.squeeze(np.array(X_val))
y_val = np.squeeze(np.array(y_val))

X_val = transform_dims(X_val)
y_val = transform_dims(y_val)
#X_val = X_val.reshape(-1,3072)

print('------VAL------')
print(X_val.shape)
print(qual_val.shape)
print(y_val.shape)

# Transformamos los datos de test para hacerlos compatibles con Keras
X_test, qual_test = Data_test[['ecg']], Data_test[['age', 'sex']]

X_test = np.squeeze(np.array(X_test))
y_test = np.squeeze(np.array(y_test))

X_test = transform_dims(X_test)
y_test = transform_dims(y_test)
#X_test = X_test.reshape(-1,3072)

print('------TEST------')
print(X_test.shape)
print(qual_test.shape)
print(y_test.shape)

#Datos para la red CONV1D
#X_train_1d = X_train.reshape(-1,3072)
#X_val_1d = X_val.reshape(-1,3072)
#X_test_1d = X_test.reshape(-1,3072)
# Out:
# ------TRAIN------
# (30172, 12, 512)
# (30172, 2)
# (30172, 27)
# ------VAL------
# (3772, 12, 512)
# (3772, 2)
# (3772, 27)
# ------TEST------
# (3772, 12, 512)
# (3772, 2)
# (3772, 27)

# %% [markdown]
# # Arquitectura 1

# %%
learning_rate = 0.01
batch_size = 64
dropout = 0.25
batch_norm = 0.8

# %%
from keras.layers import GlobalAveragePooling1D, Multiply

def SqueezeExcite(x, ratio=16):
    n_channels = x.shape[-1]
    #print(f'The number of channels is {n_channels}')
    y = GlobalAveragePooling1D()(x)
    y = Dense(n_channels//ratio, activation='relu')(y)
    y = Dense(n_channels, activation='sigmoid')(y)
    y = Multiply()([x, y])
    return y

# %%
def ResUnit(X, kernels, size):
    out = Conv1D(kernels, size, padding='same')(X)
    out = BatchNormalization(momentum=batch_norm)(out)
    out = Activation("relu")(out)
    out = Dropout(dropout)(out)
    out = Conv1D(kernels, size, padding='same')(out)
    out = BatchNormalization(momentum=batch_norm)(out)
    out = SqueezeExcite(out)
    if X.shape[-1] != out.shape[-1]:
      X = Conv1D(kernels, 1, padding='same')(X)
    out = Add()([X, out])
    out = Activation("relu")(out)
    return out

# %%
def prep_classifier():
    
    inputs_conv = Input(X_train.shape[1:])
    ecg = Conv1D(32, 12, padding='same')(inputs_conv)
    ecg = BatchNormalization(momentum=batch_norm)(ecg)
    ecg = Activation("relu")(ecg)
    ecg = MaxPooling1D()(ecg)
    ecg = ResUnit(ecg, 32, 12)
    ecg = ResUnit(ecg, 32, 12)
    ecg = ResUnit(ecg, 64, 7)
    ecg = ResUnit(ecg, 64, 7)
    ecg = ResUnit(ecg, 128, 7)
    ecg = ResUnit(ecg, 128, 7)
    ecg = ResUnit(ecg, 256, 7)
    ecg = ResUnit(ecg, 256, 7)
    ecg = Flatten()(ecg)

    inputs_rnn = Input(X_train.shape[1:])
    time = Bidirectional(LSTM(16,return_sequences=True))(inputs_rnn)
    time = Bidirectional(LSTM(16,return_sequences=True), merge_mode = "ave")(time)
    time = Flatten()(time)

    qdata_input = Input(shape=(2))
    qdata = Dense(10)(qdata_input)
    
    join = Concatenate()([ecg, time, qdata])
    join = Dense(256)(join)
    join = BatchNormalization(momentum=batch_norm)(join)
    join = Activation("relu")(join)
    join = Dense(128)(join)
    join = BatchNormalization(momentum=batch_norm)(join)
    join = Activation("relu")(join)
    join = Dense(64)(join)
    join = BatchNormalization(momentum=batch_norm)(join)
    join = Activation("relu")(join)

    outputs = Dense(27,activation="sigmoid")(join)

    classifier = Model(inputs=[inputs_conv, inputs_rnn, qdata_input], outputs=outputs)
    classifier.compile(optimizer='adam' , loss='binary_crossentropy', metrics=['accuracy', 'AUC'])
    plot_model(classifier)
    return classifier

# %%
clf = prep_classifier()
_ = plot_model(clf,
    to_file= TRIAL_PATH + '/model_scheme.png',
    show_shapes=True,
    show_dtype=True,
    show_layer_names=False)

rlrop = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10)
es = EarlyStopping(monitor='val_accuracy', mode='max' , verbose=1 , patience=5 )
mc = ModelCheckpoint('best_model.h5', monitor='val_accuracy' , mode='max' , verbose=1 , save_best_only=True)

# %%
clf.summary()

# %%
import time
start_time = time.time()
history = clf.fit([X_train, X_train, qual_train], y_train, batch_size=64, epochs=50, validation_data=([X_val, X_val, qual_val],y_val))
time_spend = time.time() - start_time
# Out:
# Epoch 1/50
# 472/472 [==============================] - 67s 50ms/step - loss: 0.2061 - accuracy: 0.3860 - auc: 0.8041 - val_loss: 0.1522 - val_accuracy: 0.4112 - val_auc: 0.8765
# Epoch 2/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1502 - accuracy: 0.4164 - auc: 0.8827 - val_loss: 0.1496 - val_accuracy: 0.4099 - val_auc: 0.8838
# Epoch 3/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1471 - accuracy: 0.4210 - auc: 0.8889 - val_loss: 0.1476 - val_accuracy: 0.4290 - val_auc: 0.8873
# Epoch 4/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1438 - accuracy: 0.4287 - auc: 0.8949 - val_loss: 0.1446 - val_accuracy: 0.4266 - val_auc: 0.8936
# Epoch 5/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1407 - accuracy: 0.4320 - auc: 0.9009 - val_loss: 0.1435 - val_accuracy: 0.4234 - val_auc: 0.8964
# Epoch 6/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.1379 - accuracy: 0.4384 - auc: 0.9061 - val_loss: 0.1412 - val_accuracy: 0.4327 - val_auc: 0.9010
# Epoch 7/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.1350 - accuracy: 0.4445 - auc: 0.9111 - val_loss: 0.1393 - val_accuracy: 0.4369 - val_auc: 0.9031
# Epoch 8/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.1324 - accuracy: 0.4490 - auc: 0.9154 - val_loss: 0.1381 - val_accuracy: 0.4403 - val_auc: 0.9059
# Epoch 9/50
# 472/472 [==============================] - 20s 43ms/step - loss: 0.1293 - accuracy: 0.4555 - auc: 0.9206 - val_loss: 0.1413 - val_accuracy: 0.4464 - val_auc: 0.9032
# Epoch 10/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.1263 - accuracy: 0.4584 - auc: 0.9253 - val_loss: 0.1336 - val_accuracy: 0.4555 - val_auc: 0.9148
# Epoch 11/50
# 472/472 [==============================] - 20s 43ms/step - loss: 0.1236 - accuracy: 0.4667 - auc: 0.9289 - val_loss: 0.1338 - val_accuracy: 0.4319 - val_auc: 0.9150
# Epoch 12/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1210 - accuracy: 0.4741 - auc: 0.9325 - val_loss: 0.1350 - val_accuracy: 0.4303 - val_auc: 0.9119
# Epoch 13/50
# 472/472 [==============================] - 20s 43ms/step - loss: 0.1187 - accuracy: 0.4795 - auc: 0.9353 - val_loss: 0.1321 - val_accuracy: 0.4438 - val_auc: 0.9163
# Epoch 14/50
# 472/472 [==============================] - 20s 43ms/step - loss: 0.1163 - accuracy: 0.4856 - auc: 0.9384 - val_loss: 0.1335 - val_accuracy: 0.4454 - val_auc: 0.9149
# Epoch 15/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1141 - accuracy: 0.4913 - auc: 0.9411 - val_loss: 0.1353 - val_accuracy: 0.4486 - val_auc: 0.9124
# Epoch 16/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1117 - accuracy: 0.4970 - auc: 0.9439 - val_loss: 0.1340 - val_accuracy: 0.4350 - val_auc: 0.9163
# Epoch 17/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1094 - accuracy: 0.5029 - auc: 0.9463 - val_loss: 0.1347 - val_accuracy: 0.4443 - val_auc: 0.9164
# Epoch 18/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1071 - accuracy: 0.5062 - auc: 0.9490 - val_loss: 0.1370 - val_accuracy: 0.4467 - val_auc: 0.9121
# Epoch 19/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1050 - accuracy: 0.5154 - auc: 0.9508 - val_loss: 0.1373 - val_accuracy: 0.4361 - val_auc: 0.9125
# Epoch 20/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1025 - accuracy: 0.5218 - auc: 0.9535 - val_loss: 0.1468 - val_accuracy: 0.4398 - val_auc: 0.9006
# Epoch 21/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.1000 - accuracy: 0.5262 - auc: 0.9560 - val_loss: 0.1421 - val_accuracy: 0.4236 - val_auc: 0.9055
# Epoch 22/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0979 - accuracy: 0.5310 - auc: 0.9582 - val_loss: 0.1504 - val_accuracy: 0.4199 - val_auc: 0.8986
# Epoch 23/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0948 - accuracy: 0.5381 - auc: 0.9610 - val_loss: 0.1497 - val_accuracy: 0.4329 - val_auc: 0.9008
# Epoch 24/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0926 - accuracy: 0.5483 - auc: 0.9628 - val_loss: 0.1520 - val_accuracy: 0.4234 - val_auc: 0.8975
# Epoch 25/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0902 - accuracy: 0.5547 - auc: 0.9648 - val_loss: 0.1569 - val_accuracy: 0.4282 - val_auc: 0.8942
# Epoch 26/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0876 - accuracy: 0.5617 - auc: 0.9672 - val_loss: 0.1542 - val_accuracy: 0.4268 - val_auc: 0.8955
# Epoch 27/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0851 - accuracy: 0.5663 - auc: 0.9692 - val_loss: 0.1590 - val_accuracy: 0.4390 - val_auc: 0.8923
# Epoch 28/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0828 - accuracy: 0.5700 - auc: 0.9709 - val_loss: 0.1583 - val_accuracy: 0.4295 - val_auc: 0.8925
# Epoch 29/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0800 - accuracy: 0.5792 - auc: 0.9730 - val_loss: 0.1655 - val_accuracy: 0.4332 - val_auc: 0.8890
# Epoch 30/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0779 - accuracy: 0.5828 - auc: 0.9744 - val_loss: 0.1651 - val_accuracy: 0.4266 - val_auc: 0.8868
# Epoch 31/50
# 472/472 [==============================] - 21s 45ms/step - loss: 0.0756 - accuracy: 0.5914 - auc: 0.9762 - val_loss: 0.1750 - val_accuracy: 0.4255 - val_auc: 0.8823
# Epoch 32/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0725 - accuracy: 0.5978 - auc: 0.9782 - val_loss: 0.1785 - val_accuracy: 0.4133 - val_auc: 0.8784
# Epoch 33/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0710 - accuracy: 0.6033 - auc: 0.9791 - val_loss: 0.1862 - val_accuracy: 0.4236 - val_auc: 0.8729
# Epoch 34/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0687 - accuracy: 0.6086 - auc: 0.9807 - val_loss: 0.1913 - val_accuracy: 0.4290 - val_auc: 0.8686
# Epoch 35/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0656 - accuracy: 0.6191 - auc: 0.9823 - val_loss: 0.1882 - val_accuracy: 0.3826 - val_auc: 0.8678
# Epoch 36/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0640 - accuracy: 0.6224 - auc: 0.9834 - val_loss: 0.1977 - val_accuracy: 0.4202 - val_auc: 0.8653
# Epoch 37/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0617 - accuracy: 0.6278 - auc: 0.9847 - val_loss: 0.2011 - val_accuracy: 0.4120 - val_auc: 0.8616
# Epoch 38/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0597 - accuracy: 0.6316 - auc: 0.9858 - val_loss: 0.2089 - val_accuracy: 0.4223 - val_auc: 0.8593
# Epoch 39/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0579 - accuracy: 0.6385 - auc: 0.9864 - val_loss: 0.2156 - val_accuracy: 0.4099 - val_auc: 0.8508
# Epoch 40/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0557 - accuracy: 0.6431 - auc: 0.9876 - val_loss: 0.2159 - val_accuracy: 0.4229 - val_auc: 0.8510
# Epoch 41/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.0537 - accuracy: 0.6482 - auc: 0.9885 - val_loss: 0.2300 - val_accuracy: 0.4239 - val_auc: 0.8461
# Epoch 42/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0520 - accuracy: 0.6514 - auc: 0.9893 - val_loss: 0.2190 - val_accuracy: 0.4170 - val_auc: 0.8509
# Epoch 43/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.0495 - accuracy: 0.6588 - auc: 0.9900 - val_loss: 0.2289 - val_accuracy: 0.4077 - val_auc: 0.8451
# Epoch 44/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0490 - accuracy: 0.6606 - auc: 0.9904 - val_loss: 0.2315 - val_accuracy: 0.3961 - val_auc: 0.8402
# Epoch 45/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0457 - accuracy: 0.6659 - auc: 0.9919 - val_loss: 0.2505 - val_accuracy: 0.4046 - val_auc: 0.8356
# Epoch 46/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0455 - accuracy: 0.6668 - auc: 0.9917 - val_loss: 0.2448 - val_accuracy: 0.3979 - val_auc: 0.8396
# Epoch 47/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0438 - accuracy: 0.6728 - auc: 0.9924 - val_loss: 0.2482 - val_accuracy: 0.3969 - val_auc: 0.8361
# Epoch 48/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0417 - accuracy: 0.6780 - auc: 0.9933 - val_loss: 0.2643 - val_accuracy: 0.4030 - val_auc: 0.8276
# Epoch 49/50
# 472/472 [==============================] - 21s 43ms/step - loss: 0.0412 - accuracy: 0.6760 - auc: 0.9933 - val_loss: 0.2759 - val_accuracy: 0.4069 - val_auc: 0.8311
# Epoch 50/50
# 472/472 [==============================] - 21s 44ms/step - loss: 0.0392 - accuracy: 0.6813 - auc: 0.9939 - val_loss: 0.2683 - val_accuracy: 0.4146 - val_auc: 0.8361

# %%
plt.style.use('seaborn')
fig, axs = plt.subplots(1,2, figsize=(15,5), dpi=100)
axs[0].plot(history.history['accuracy'], color='r', label='train')
axs[0].plot(history.history['val_accuracy'], color='b', label='validation')
axs[0].legend(loc = 'upper left', prop={'size':12})
axs[0].set_title('ACCURACY', fontsize=20)
axs[1].plot(history.history['loss'], color='r', label='train')
axs[1].plot(history.history['val_loss'], color='b', label='validation')
axs[1].set_title('LOSS', fontsize=20)
axs[1].legend(loc = 'upper right', prop={'size':12})
fig.savefig(TRIAL_PATH+'/ACCURACY and LOSS')

# %% [markdown]
# # Save model

# %%
clf.save(TRIAL_PATH+'/model_'+TRIAL_NUMBER+'.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %% [markdown]
# # Analysing model results

# %%
from keras.utils import np_utils
from sklearn.metrics import classification_report, multilabel_confusion_matrix, confusion_matrix

predictions = clf.predict([X_test, X_test, qual_test])

mult_label = []
for prediction in predictions:
  mult_label.append(np.where(prediction > 0.5, 1, 0))

etiq = []
[etiq.append(abbv) for abbv in csv_file['Abbreviation']]
clf_rep = classification_report(y_test, mult_label, target_names=etiq)
print(classification_report(y_test, mult_label,target_names=etiq))
# Out:
#               precision    recall  f1-score   support
#
#         IAVB       0.15      0.11      0.12       226
#           AF       0.41      0.32      0.36       354
#          AFL       0.00      0.00      0.00        23
#        Brady       0.14      0.09      0.11        22
#        CRBBB       0.33      0.38      0.35        73
#        IRBBB       0.18      0.14      0.16       151
#        LAnFB       0.50      0.50      0.50       206
#          LAD       0.57      0.64      0.61       623
#         LBBB       0.55      0.64      0.59        99
#        LQRSV       0.08      0.04      0.05        57
#       NSIVCB       0.07      0.03      0.04        95
#           PR       0.26      0.19      0.22        26
#          PAC       0.08      0.03      0.05       174
#          PVC       0.00      0.00      0.00        17
#          LPR       0.25      0.05      0.09        39
#          LQT       0.23      0.11      0.15       154
#          QAb       0.08      0.03      0.05        91
#          RAD       0.24      0.21      0.23        43
#         RBBB       0.68      0.43      0.53       239
#           SA       0.09      0.05      0.07       113
#           SB       0.52      0.39      0.45       244
#          NSR       0.74      0.82      0.78      2111
#        STach       0.71      0.50      0.59       222
#         SVPB       0.10      0.05      0.07        20
#          TAb       0.29      0.22      0.25       488
#         TInv       0.13      0.04      0.06       120
#          VPB       0.00      0.00      0.00        39
#
#    micro avg       0.56      0.49      0.52      6069
#    macro avg       0.27      0.22      0.24      6069
# weighted avg       0.50      0.49      0.49      6069
#  samples avg       0.55      0.53      0.52      6069
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = multilabel_confusion_matrix(y_test, mult_label)

# %% [markdown]
# # Generating a confusion matrix for class predictions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


def print_confusion_matrix(confusion_matrix, axes, class_label, class_names, fontsize=14):

    df_cm = pd.DataFrame(
        confusion_matrix, index=class_names, columns=class_names,
    )

    try:
        heatmap = sns.heatmap(df_cm, annot=True, fmt="d", cbar=False, ax=axes)
    except ValueError:
        raise ValueError("Confusion matrix values must be integers.")
    heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0, ha='right', fontsize=fontsize)
    heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45, ha='right', fontsize=fontsize)
    axes.set_xlabel('True label')
    axes.set_ylabel('Predicted label')
    axes.set_title(class_label)

# %%
csv_file = pd.read_csv('/content/drive/MyDrive/TFM_DATA/Dx_snomed_valid.csv', delimiter=';')
labels=csv_file['Abbreviation']
fig, ax = plt.subplots(4, 8, figsize=(18, 10))
    
for axes, cfs_matrix, label in zip(ax.flatten(), cm, labels):
    print_confusion_matrix(cfs_matrix, axes, label, ["N", "Y"])
    
fig.tight_layout()
plt.savefig(TRIAL_PATH+'/confusion_matrix')
plt.show()

# %% [markdown]
# # Saving the model results

# %%
def txt_generator():
    with open(os.path.join(TRIAL_PATH, FILE_NAME), 'w') as f:
      f.write(TRIAL_NUMBER+'\n')
      f.write('Training this model took ' + str(float(time_spend/60))+' minutes...\n')
      f.write('--------------------------------------------------------'+'\n')
      f.write('Dataset used: ' + DATASET + '\n')
      f.write('Data dimensions'+'\n')
      f.write('\tTrain: '+'\n')
      f.write('\t\t'+'ECG: '+ str(X_train.shape)+'\n')
      f.write('\t\t'+'Qualitative: '+str(qual_train.shape)+'\n')
      f.write('\t\t'+'Labels: '+str(y_train.shape)+'\n')
      f.write('\tValidation: '+'\n')
      f.write('\t\t'+'ECG: '+str(X_val.shape)+'\n')
      f.write('\t\t'+'Qualitative: '+str(qual_val.shape)+'\n')
      f.write('\t\t'+'Labels: '+str(y_val.shape)+'\n')
      f.write('\tTest: '+'\n')
      f.write('\t\t'+'ECG: '+str(X_test.shape)+'\n')
      f.write('\t\t'+'Qualitative: '+str(qual_test.shape)+'\n')
      f.write('\t\t'+'Labels: '+str(y_test.shape)+'\n')
      f.write('Hyper Parameters\n')
      f.write('\t\t'+'Learning Rate '+ str(learning_rate) +'\n')
      f.write('\t\t'+'Drop Out '+str(dropout) +'\n')
      f.write('\t\t'+'Batch Normalisation '+str(batch_norm) +'\n\n')
      f.write('Clasification Report'+'\n')
      f.write(str(clf_rep)+'\n\n')

# %%
txt_generator()

# %% [markdown]
# # Loading existing model

# %%
clf = load_model(TRIAL_PATH+'/model_' + TRIAL_NUMBER + '.h5')

# %% [markdown]
# # ROC AUC curves

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.metrics import roc_curve, auc

m2_probs = clf.predict([X_test,X_test,qual_test])

# %%
# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(27):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], m2_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), m2_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# %%
plt.figure()
lw = 2
clase = 5
plt.plot(fpr[clase], tpr[clase], color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc[clase])
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic example')
plt.legend(loc="lower right")
plt.show()
